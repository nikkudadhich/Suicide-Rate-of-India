# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

df = pd.read_csv("Suicides_in_India.csv")

# %%
df
# Out:
#                 State  Year      Type_code  \
# 0       A & N Islands  2001         Causes
# 1       A & N Islands  2001         Causes
# 2       A & N Islands  2001         Causes
# 3       A & N Islands  2001         Causes
# 4       A & N Islands  2001         Causes
# ...               ...   ...            ...
# 237514    West Bengal  2012  Social_Status
# 237515    West Bengal  2012  Social_Status
# 237516    West Bengal  2012  Social_Status
# 237517    West Bengal  2012  Social_Status
# 237518    West Bengal  2012  Social_Status
#
#                                            Type  Gender Age_group  Total
# 0                            Illness (Aids/STD)  Female      0-14      0
# 1       Bankruptcy or Sudden change in Economic  Female      0-14      0
# 2       Cancellation/Non-Settlement of Marriage  Female      0-14      0
# 3             Physical Abuse (Rape/Incest Etc.)  Female      0-14      0
# 4                                 Dowry Dispute  Female      0-14      0
# ...

# %% [markdown]
# # DATA CLEANING

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237519 entries, 0 to 237518
# Data columns (total 7 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   State      237519 non-null  object
#  1   Year       237519 non-null  int64
#  2   Type_code  237519 non-null  object
#  3   Type       237519 non-null  object
#  4   Gender     237519 non-null  object
#  5   Age_group  237519 non-null  object
#  6   Total      237519 non-null  int64
# dtypes: int64(2), object(5)
# memory usage: 12.7+ MB

# %%
df.rename(columns={'state':'GENDER','year':'RATIO'},inplace=True) # rename the columns

# %%
df.describe()
# Out:
#                 Year          Total
# count  237519.000000  237519.000000
# mean     2006.500448      55.034477
# std         3.452240     792.749038
# min      2001.000000       0.000000
# 25%      2004.000000       0.000000
# 50%      2007.000000       0.000000
# 75%      2010.000000       6.000000
# max      2012.000000   63343.000000

# %%
df.sample(5)
# Out:
#                 State  Year      Type_code                  Type Gender  \
# 4308    A & N Islands  2008  Means_adopted            By Machine   Male
# 145633        Manipur  2007  Means_adopted          By Fire-Arms   Male
# 196316         Sikkim  2001  Means_adopted            By Hanging   Male
# 189522      Rajasthan  2001  Means_adopted          By Fire-Arms   Male
# 140316    Maharashtra  2010         Causes  Death of Dear Person   Male
#
#        Age_group  Total
# 4308       45-59      0
# 145633      0-14      0
# 196316     30-44     12
# 189522     30-44      4
# 140316      0-14      0

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("Suicides_in_India.csv")

# %%
sns.set_palette(sns.color_palette(["#FF5733", "#FF5733", "#FF5733", "#FF5733", "#FF5733"]))

# %%
# Visualization 1: Bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x='State', y='Total', data=df)
plt.title('Total by State')
plt.xlabel('State')
plt.ylabel('Total')
plt.xticks(rotation=90)
plt.show()

# %%
 #Visualization 2: Count plot
plt.figure(figsize=(10, 6))
sns.countplot(x='Year', data=df)
plt.title('Count by Year')
plt.xlabel('Year')
plt.ylabel('Count')
plt.show()

# %%
# Visualization 3: Box plot
plt.figure(figsize=(12, 6))
sns.boxplot(x='Type', y='Total', data=df)
plt.title('Total by Type')
plt.xlabel('Type')
plt.ylabel('Total')
plt.xticks(rotation=90)
plt.show()

# %%
# Visualization 4: Violin plot
plt.figure(figsize=(10, 6))
sns.violinplot(x='Gender', y='Total', data=df)
plt.title('Total by Gender')
plt.xlabel('Gender')
plt.ylabel('Total')
plt.show()

# %%
# Visualization 5: Scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Year', y='Total', data=df)
plt.title('Total over Years')
plt.xlabel('Year')
plt.ylabel('Total')
plt.show()

# %%
# Visualization 6: Line plot
plt.figure(figsize=(10, 6))
sns.lineplot(x='Year', y='Total', data=df)
plt.title('Total over Years')
plt.xlabel('Year')
plt.ylabel('Total')
plt.show()

# %%
 #Visualization 7: Histogram
plt.figure(figsize=(10, 6))
sns.histplot(df['Total'], bins=20, kde=True, color='#FF5733')
plt.title('Total Histogram')
plt.xlabel('Total')
plt.ylabel('Frequency')
plt.show()

# %%
# expenditure of 4 department

slices= [43.38,56.61]

# department name
depts=["women","male"]

#color for each department
cols=["cyan","gold"]

# create pie chart

plt.pie(slices, labels=depts, colors=cols,startangle=90, explode=(0,0.2), shadow=True, autopct="%.1f%%")

# set title and legend
plt.title("suicide case in india")
plt.legend()

# show the pie chart
plt.show()

# %%
df.head()
# Out:
#            State  Year Type_code                                     Type  \
# 0  A & N Islands  2001    Causes                       Illness (Aids/STD)
# 1  A & N Islands  2001    Causes  Bankruptcy or Sudden change in Economic
# 2  A & N Islands  2001    Causes  Cancellation/Non-Settlement of Marriage
# 3  A & N Islands  2001    Causes        Physical Abuse (Rape/Incest Etc.)
# 4  A & N Islands  2001    Causes                            Dowry Dispute
#
#    Gender Age_group  Total
# 0  Female      0-14      0
# 1  Female      0-14      0
# 2  Female      0-14      0
# 3  Female      0-14      0
# 4  Female      0-14      0

# %%
df.shape
# Out:
# (237519, 7)

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >
